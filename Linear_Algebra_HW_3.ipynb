# %% [markdown]
# <a href="https://colab.research.google.com/github/nedokormysh/GB_Linear_Algebra/blob/lesson3/Linear_Algebra_HW_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# __1.__ Найти собственные векторы и собственные значения для линейного оператора, заданного матрицей
#
# $$A=\begin{pmatrix}
# -1 & -6\\
# 2 & 6
# \end{pmatrix}.$$
#
# $$det(\textbf{A}-\lambda\textbf{I})=\begin{vmatrix}
# -1-\lambda & -6\\
# 2 & 6-\lambda
# \end{vmatrix} = \lambda^{2}-(-1 + 6)\lambda + ((-1) \cdot 6 + 6 \cdot 2) = \lambda^{2}-5\lambda + 6$$
# <br>
# $$det(\textbf{A}-\lambda\textbf{I})=0$$
#
# $$\lambda^{2}-5\lambda + 6 = 0$$
#
# Собственные числа.
#
# $$λ_1 = 3$$
#
# $$λ_2 = 2$$
#
# Найдём собственные вектора.
#
# $$λ_1 = 3$$
#
# $$\begin{pmatrix}
# -1 & -6\\
# 2 & 6
# \end{pmatrix}
# \begin{pmatrix}
# x_{1}\\
# x_{2}
# \end{pmatrix}=
# 3
# \begin{pmatrix}
# x_{1}\\
# x_{2}
# \end{pmatrix}.
# $$
#
# $$\begin{cases}
# -x_{1} - 6 \cdot x_{2} = 3 · x_{1} \\
# 2 \cdot x_{1} + 6 \cdot x_{2} = 3 \cdot x_{2}
# \end{cases}$$
#
# $$\begin{cases}
# - 6 \cdot x_{2} = 4 · x_{1} \\
# 2 \cdot x_{1} + 6 \cdot x_{2} = 3 \cdot x_{2}
# \end{cases}$$
#
# $$\begin{cases}
#  x_{1} = - \frac{3}{2} x_2 \\
# -3 \cdot x_2 + 6 \cdot x_{2} = 3 \cdot x_{2}
# \end{cases}$$
#
# $$\begin{cases}
#  x_{1} = - \frac{3}{2} x_2 \\
# x_2 = x_{2}
# \end{cases}$$
#
# $$\Rightarrow \forall x_2 \Rightarrow x_2 = 1, x_1 = -\frac{3}{2}$$
#
# $$λ_2 = 2$$
#
# $$\begin{pmatrix}
# -1 & -6\\
# 2 & 6
# \end{pmatrix}
# \begin{pmatrix}
# x_{1}\\
# x_{2}
# \end{pmatrix}=
# 2
# \begin{pmatrix}
# x_{1}\\
# x_{2}
# \end{pmatrix}
# $$
#
# $$\begin{cases}
# -x_{1} - 6 \cdot x_{2} = 2 · x_{1} \\
# 2 \cdot x_{1} + 6 \cdot x_{2} = 2 \cdot x_{2}
# \end{cases}$$
#
# $$\begin{cases}
# - 6 \cdot x_{2} = 3 · x_{1} \\
# x_{1} + 3 \cdot x_{2} = x_{2}
# \end{cases}$$
#
# $$\begin{cases}
# x_1 = -2 x_2 \\
# -2 \cdot x_2 + 3 \cdot x_{2} = x_{2}
# \end{cases}$$
#
# $$\Rightarrow \forall x_2 \Rightarrow x_2 = 1, x_1 = - 2$$

# %%
import numpy as np

np.set_printoptions(precision=2, suppress=True)

a = np.array([[-1, -6], [2, 6]])
w, v = np.linalg.eig(a)
 
print(f'Матрица A:\n{a}')
print(f'Собственные значения:\n{w}')
print(f'Собственные векторы:\n{v}')
# Out:
# Матрица A:
# [[-1 -6]
#  [ 2  6]]
# Собственные значения:
# [2. 3.]
# Собственные векторы:
# [[-0.89  0.83]
#  [ 0.45 -0.55]]

# %% [markdown]
# __2.__ Дан оператор поворота на 180 градусов, задаваемый матрицей
#
# $$A=\begin{pmatrix}
# -1 & 0\\
# 0 & -1
# \end{pmatrix}.$$
#
# Показать, что __любой__ вектор является для него собственным.
#
# $$det(\textbf{A}-\lambda\textbf{I})=\begin{vmatrix}
# -1 -\lambda & 0\\
# 0 & -1 -\lambda
# \end{vmatrix} = \lambda^{2} + 2 λ +1$$
# <br>
# $$\lambda = -1$$
#
# Действие этого оператора сводится к умножению числа на вектор. Любой вектор будет являться собственным.
#
# $$\begin{pmatrix}
# -1 & 0\\
# 0 & -1
# \end{pmatrix}
# \begin{pmatrix}
# x_{1}\\
# x_{2}
# \end{pmatrix}=
# -1
# \begin{pmatrix}
# x_{1}\\
# x_{2}
# \end{pmatrix}$$
#
# $$\begin{cases}
# -x_{1} - 0 \cdot x_{2} = -1 · x_{1} \\
# 0 \cdot x_{1} - x_{2} = -1 \cdot x_{2}
# \end{cases}$$
#
# $$\begin{cases}
# -x_{1} = -x_{1}, \\
# - x_{2} = -x_{2}
# \end{cases}$$
#
# $$\Rightarrow \forall x_1, x_2$$

# %% [markdown]
# __3.__ Пусть линейный оператор задан матрицей
#
# $$A=\begin{pmatrix}
# 1 & 1\\
# -1 & 3
# \end{pmatrix}.$$
#
# Установить, является ли вектор $x=(1,1)$ собственным вектором этого линейного оператора.
#
#
# $\begin{pmatrix}
# 1 & 1\\
# -1 & 3
# \end{pmatrix}
# \begin{pmatrix}
# 1\\
# 1
# \end{pmatrix}=
# \begin{pmatrix}
# 2\\
# 2
# \end{pmatrix}=
# 2\begin{pmatrix}
# 1\\
# 1
# \end{pmatrix}
# =\lambda\begin{pmatrix}
# 1\\
# 1
# \end{pmatrix}$
#
# <br>
#
# $
# \begin{cases}
# \lambda=2\\
# \lambda=2
# \end{cases}
# \Rightarrow
# \lambda=2$
#
# $$\textbf{A}x=\lambda x.$$
#
# _Собственный вектор_ оператора $\textbf{A}$ — это такой ненулевой вектор, действие оператора на который сводится к умножению его на число. В данном случае вектор $x=(1,1)$ является собственным вектором линейного оператора, заданного матрицей $A$. Собственное значение $\lambda=2$.

# %% [markdown]
# **4.** Пусть линейный оператор задан матрицей
#
# $$A=\begin{pmatrix} 0 & 3 & 0\\ 3 & 0 & 0\\ 0 & 0 & 3 \end{pmatrix}.$$
#
# Установить, является ли вектор $x=(3, -3, -4)$ собственным вектором этого линейного оператора.
#
# $$\begin{pmatrix} 0 & 3 & 0\\
# 3 & 0 & 0\\
# 0 & 0 & 3 \end{pmatrix}
# \begin{pmatrix} 3 \\
# -3 \\
# -4\end{pmatrix} = \lambda
# \begin{pmatrix} 3 \\
# -3 \\
# -4\end{pmatrix}$$
#
# $$\begin{cases}
# 0 - 9 + 0  = 3 λ \\
# 9 - 0 - 0 = -3 λ \\
# 0 + 0 - 12 = -4 λ
# \end{cases}$$
#
# $$\begin{cases}
# -9 = 3 λ \\
# 9 = -3 λ \\
# - 12 = -4 λ
# \end{cases}$$
#
# $$\begin{cases}
# - 3 =  λ \\
# - 3 = λ \\
# 3 = λ
# \end{cases}$$
#
# $\Rightarrow$ Вектор x не является собственным вектором.
